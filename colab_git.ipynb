# %% [markdown]
# # Colab과 GitHub 연동하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://leeyeonjun85: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@github.com/leeyeonjun85/csai.git
# Out:
# Cloning into 'csai'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 21 (delta 6), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
cd csai
# Out:
# [Errno 2] No such file or directory: 'csai'
# /content/csai

# %%
# !git config --global user.email 'leeyeonjun85@gmail.com'
# !git config --global user.name 'leeyeonjun85'

# %%
# !git add test1.ipynb

# %%
pwd # 현재 디렉토리 보기
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %%
ls # 디렉토리 안의 파일과 디렉토리 보기
# Out:
# leeyeonjun-intro.ipynb  test12.ipynb

# %%
cd ..
# Out:
# /content

# %%
cd drive/MyDrive/Colab Notebooks/csai
# Out:
# /content/drive/MyDrive/Colab Notebooks/csai

# %%
# !git add --all

# %%
# !git commit -m 'test1'
# !git push
# Out:
# [main e2f3d08] test1
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled0.ipynb
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 504 bytes | 100.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/leeyeonjun85/csai.git
#    6f198ae..e2f3d08  main -> main
