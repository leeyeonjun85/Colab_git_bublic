# %% [markdown]
# # base setting

# %%
# Google drive mout
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# pd.options.display.float_format = '{:,.2f}'.format # 천단위 , + 소수점2자리

# %%
drive_path = 'drive/Shareddrives/coding/'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import statsmodels.api as sm
from vega_datasets import data
from tabulate import tabulate

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
plt.rc('font', family='NanumGothic')

# %%
# !apt -qq -y install fonts-nanum > /dev/null
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %% [markdown]
# <br>
# <br>
# <hr>
# <hr>
# <hr>
# <hr>
# <br>
# <br>

# %% [markdown]
# # seaborn
#
# [공식: seaborn-data list](https://github.com/mwaskom/seaborn-data)
# [코딩유치원](https://coding-kindergarten.tistory.com/127)

# %% [markdown]
# ## 붓꽃 데이터 셋 (iris)
#
# [공식: Iris Data Set](https://archive.ics.uci.edu/ml/datasets/iris)

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 타이타닉 데이터 셋 (titanic)

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## 팁 데이터 셋 (tips)

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Statsmodels
# [공식 statsmodels](https://www.statsmodels.org/devel/datasets/index.html)
#
# [Rdatasets, Available datasets](https://vincentarelbundock.github.io/Rdatasets/articles/data.html)

# %% [markdown]
# ## CES11
# - Rdatasets : 176	carData	CES11
# - 2011 Canadian National Election Study, With Attitude Toward Abortion

# %%
ces11 = sm.datasets.get_rdataset('CES11', 'carData')
print(tabulate(ces11.data.sample(10), headers='keys'))
# Out:
#         id  province      population    weight  gender    abortion    importance    education    urban
# ----  ----  ----------  ------------  --------  --------  ----------  ------------  -----------  -------
# 1284   370  ON               9439960  13466.4   Female    No          somewhat      somePS       urban
#  579  2311  QC               5996930   6153.85  Male      No          not           somePS       urban
# 1768  1817  PE                105780    870.62  Female    No          somewhat      bachelors    rural
#  235  1429  NB                582625   4958.51  Female    Yes         very          lessHS       rural
# 1117  2751  ON               9439960   4488.81  Female    No          somewhat      college      urban
# 1528  1902  AB               2515180  17406.1   Female    No          somewhat      HS           urban
# 1457  1977  SK                734250   4721.86  Male      No          not           HS           rural
# ...

# %%
print(ces11.__doc__)
# Out:
# .. container::
#
#    ===== ===============
#    CES11 R Documentation
#    ===== ===============
#
#    .. rubric:: 2011 Canadian National Election Study, With Attitude
#       Toward Abortion
#       :name: canadian-national-election-study-with-attitude-toward-abortion
#
#    .. rubric:: Description
#       :name: description
#
#    Data are drawn from the 2011 Canadian National Election Study,
#    including a question on banning abortion and variables related to the
#    sampling design.
#
#    .. rubric:: Usage
#       :name: usage
#
#    ::
#
#       data("CES11")
#
#    .. rubric:: Format
#       :name: format
#
#    A data frame with 2231 observations on the following 9 variables.
#
#    ``id``
#       Household ID number.
#
#    ``province``
#       a factor with (alphabetical) levels ``AB``, ``BC``, ``MB``,
#       ``NB``, ``NL``, ``NS``, ``ON``, ``PE``, ``QC``, ``SK``; the sample
#       was stratified by province.
#
#    ``population``
# ...

# %% [markdown]
# # Scikit-Learn
#
# [sklearn.datasets](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.datasets)

# %% [markdown]
# ## iris

# %%
from sklearn.datasets import load_iris
iris = load_iris()

df_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
df_iris['target'] = iris.target
print(tabulate(df_iris.sample(10), headers='keys'))
# Out:
#        sepal length (cm)    sepal width (cm)    petal length (cm)    petal width (cm)    target
# ---  -------------------  ------------------  -------------------  ------------------  --------
#  84                  5.4                 3                    4.5                 1.5         1
#   9                  4.9                 3.1                  1.5                 0.1         0
# 105                  7.6                 3                    6.6                 2.1         2
#  93                  5                   2.3                  3.3                 1           1
#  11                  4.8                 3.4                  1.6                 0.2         0
#  48                  5.3                 3.7                  1.5                 0.2         0
# 124                  6.7                 3.3                  5.7                 2.1         2
#  63                  6.1                 2.9                  4.7                 1.4         1
# ...

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %% [markdown]
# # Vaga Datasets
# - [참고: (공식 - 데이터셋) Vega Datasets](https://github.com/vega/vega-datasets/blob/master/SOURCES.md)
#   - 함수 data.list_datasets() 로 목록 확인 가능
# - [참고: (공식 - 패키지) vega_datasets 패키지](https://github.com/jakevdp/vega_datasets)

# %% [markdown]
# ## airports

# %%
airports = data.airports()
print(tabulate(airports.sample(10), headers='keys'))
# Out:
#       iata    name                            city            state    country      latitude    longitude
# ----  ------  ------------------------------  --------------  -------  ---------  ----------  -----------
# 1774  HTW     Lawrence County Airpark,Inc     Chesapeake      OH       USA           38.4192     -82.4943
#  796  AGZ     Wagner Municipal                Wagner          SD       USA           43.0633     -98.2962
# 1999  KVC     King Cove                       King Cove       AK       USA           55.1163    -162.266
# 1031  BWP     Harry Stern                     Wahpeton        ND       USA           46.2464     -96.6057
#  462  4R9     Dauphin Island                  Dauphin Island  AL       USA           30.2605     -88.1275
#  846  ANY     Anthony Municipal               Anthony         KS       USA           37.1585     -98.0796
# 2768  RIC     Richmond International          Richmond        VA       USA           37.5052     -77.3197
# ...
